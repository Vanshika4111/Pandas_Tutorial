# %%
import pandas as pd

# %%
titanic=pd.read_csv("titanic.csv",index_col=0)
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# ...               ...     ...
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# ...                                                        ...     ...   ...
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# ...               ...     ...
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# ...                                                        ...     ...   ...
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic=pd.read_csv("titanic.csv")
pd.set_option('display.max_rows', 6)
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# ..           ...       ...     ...
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# ..                                                 ...     ...   ...    ...
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# ..           ...       ...     ...
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# ..                                                 ...     ...   ...    ...
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic.shape
# Out:
# (891, 12)

# %%
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
titanic.isnull().tail(20).sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
#                ..
# Fare            0
# Cabin          15
# Embarked        0
# Length: 12, dtype: int64

# %%
titanic.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# ..     ...    ...       ...
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
#               ...
# Fare             0
# Cabin          687
# Embarked         2
# Length: 12, dtype: int64

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# ..          ...       ...     ...
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# ..                                                ...     ...   ...    ...
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#     Parch            Ticket     Fare Cabin Embarked
# ...

# %%
titanic.tail(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 871          872         1       1
# 872          873         0       1
# 873          874         0       3
# ..           ...       ...     ...
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                          Carlsson, Mr. Frans Olof    male  33.0      0
# 873                       Vander Cruyssen, Mr. Victor    male  47.0      0
# ..                                                ...     ...   ...    ...
# 888          Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                             Behr, Mr. Karl Howell    male  26.0      0
# 890                               Dooley, Mr. Patrick    male  32.0      0
#
#      Parch      Ticket     Fare        Cabin Embarked
# ...

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
#                 ...
# Fare           float64
# Cabin           object
# Embarked        object
# Length: 12, dtype: object

# %%
titanic.to_excel("titanic.xlsx",sheet_name="passengers",index=False)

# %%
titanic=pd.read_excel("titanic.xlsx",sheet_name="passengers")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
age=titanic["Age"]

# %%
age.head()
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
type(age)
# Out:
# pandas.core.series.Series

# %%
age.shape
# Out:
# (891,)

# %%
age_sex=titanic[["Age","Sex"]]

# %%
["Age","Sex"]
# Out:
# ['Age', 'Sex']

# %%
age_sex.head()
# Out:
#     Age     Sex
# 0  22.0    male
# 1  38.0  female
# 2  26.0  female
# 3  35.0  female
# 4  35.0    male

# %%
type(age_sex)
# Out:
# pandas.core.frame.DataFrame

# %%
age_sex.shape
# Out:
# (891, 2)

# %%
above_35=titanic[titanic["Age"]>35]

# %%
above_35
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# ..           ...       ...     ...
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 873                        Vander Cruyssen, Mr. Victor    male  47.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
#
#      Parch    Ticket     Fare Cabin Embarked
# ...

# %%
above_35.head(10)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 6             7         0       1
# 11           12         1       1
# ..          ...       ...     ...
# 33           34         0       2
# 35           36         0       1
# 40           41         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                ...     ...   ...    ...
# 33                              Wheadon, Mr. Edward H    male  66.0      0
# 35                     Holverson, Mr. Alexander Oskar    male  42.0      1
# 40     Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
#
#     Parch      Ticket     Fare Cabin Embarked
# ...

# %%
titanic["Age"]>35#conditional expression
# Out:
# 0      False
# 1       True
# 2      False
#        ...
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
above_35.shape
# Out:
# (217, 12)

# %%
cabin_23=titanic[titanic["Pclass"].isin([2,3])]#isin is a conditonal function

# %%
cabin_23.head(20)
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  \
# 0             1         0       3        Braund, Mr. Owen Harris    male
# 2             3         1       3         Heikkinen, Miss. Laina  female
# 4             5         0       3       Allen, Mr. William Henry    male
# ..          ...       ...     ...                            ...     ...
# 21           22         1       2          Beesley, Mr. Lawrence    male
# 22           23         1       3    McGowan, Miss. Anna "Annie"  female
# 24           25         0       3  Palsson, Miss. Torborg Danira  female
#
#      Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0   22.0      1      0         A/5 21171   7.2500   NaN        S
# 2   26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4   35.0      0      0            373450   8.0500   NaN        S
# ..   ...    ...    ...               ...      ...   ...      ...
# ...

# %%
titanic["Pclass"].isin([2,3])
# Out:
# 0       True
# 1      False
# 2       True
#        ...
# 888     True
# 889    False
# 890     True
# Name: Pclass, Length: 891, dtype: bool

# %%
cabin_23=titanic[(titanic["Pclass"]==2)|(titanic["Pclass"]==3)]

# %%
cabin_23.head(20)
# Out:
#     PassengerId  Survived  Pclass                           Name     Sex  \
# 0             1         0       3        Braund, Mr. Owen Harris    male
# 2             3         1       3         Heikkinen, Miss. Laina  female
# 4             5         0       3       Allen, Mr. William Henry    male
# ..          ...       ...     ...                            ...     ...
# 21           22         1       2          Beesley, Mr. Lawrence    male
# 22           23         1       3    McGowan, Miss. Anna "Annie"  female
# 24           25         0       3  Palsson, Miss. Torborg Danira  female
#
#      Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0   22.0      1      0         A/5 21171   7.2500   NaN        S
# 2   26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4   35.0      0      0            373450   8.0500   NaN        S
# ..   ...    ...    ...               ...      ...   ...      ...
# ...

# %%
(titanic["Pclass"]==2)|(titanic["Pclass"]==3)
# Out:
# 0       True
# 1      False
# 2       True
#        ...
# 888     True
# 889    False
# 890     True
# Name: Pclass, Length: 891, dtype: bool

# %%
age_notan=titanic[titanic["Age"].notna()]

# %%
cabin=titanic[titanic["Cabin"].notna()]

# %%
cabin.tail(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 796          797         1       1
# 802          803         1       1
# 806          807         0       1
# ..           ...       ...     ...
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                               Name     Sex   Age  SibSp  \
# 796                    Leader, Dr. Alice (Farnham)  female  49.0      0
# 802            Carter, Master. William Thornton II    male  11.0      1
# 806                         Andrews, Mr. Thomas Jr    male  39.0      0
# ..                                             ...     ...   ...    ...
# 879  Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                   Graham, Miss. Margaret Edith  female  19.0      0
# 889                          Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch  Ticket      Fare    Cabin Embarked
# 796      0   17465   25.9292      D17        S
# ...

# %%
age_notan.tail(20)
# Out:
#      PassengerId  Survived  Pclass  \
# 869          870         1       3
# 870          871         0       3
# 871          872         1       1
# ..           ...       ...     ...
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 869                   Johnson, Master. Harold Theodor    male   4.0      1
# 870                                 Balkic, Mr. Cerin    male  26.0      0
# 871  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# ..                                                ...     ...   ...    ...
# 887                      Graham, Miss. Margaret Edith  female  19.0      0
# 889                             Behr, Mr. Karl Howell    male  26.0      0
# 890                               Dooley, Mr. Patrick    male  32.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# ...

# %%
titanic["Age"].notna()
# Out:
# 0       True
# 1       True
# 2       True
#        ...
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool

# %%
age_notan.shape
# Out:
# (714, 12)

# %%
passenger_detail=titanic.loc[titanic["Age"]>35,"Name" ]
passenger_detail
# Out:
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                                McCarthy, Mr. Timothy J
# 11                              Bonnell, Miss. Elizabeth
#                              ...
# 873                          Vander Cruyssen, Mr. Victor
# 879        Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)
# 885                 Rice, Mrs. William (Margaret Norton)
# Name: Name, Length: 217, dtype: object

# %%
passenger_detail.head(10)
# Out:
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...
# 6                               McCarthy, Mr. Timothy J
# 11                             Bonnell, Miss. Elizabeth
#                             ...
# 33                                Wheadon, Mr. Edward H
# 35                       Holverson, Mr. Alexander Oskar
# 40       Ahlin, Mrs. Johan (Johanna Persdotter Larsson)
# Name: Name, Length: 10, dtype: object

# %%
titanic.iloc[9:25,2:5]#9 starting until 24 10 till 25
# Out:
#     Pclass                                 Name     Sex
# 9        2  Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3      Sandstrom, Miss. Marguerite Rut  female
# 11       1             Bonnell, Miss. Elizabeth  female
# ..     ...                                  ...     ...
# 22       3          McGowan, Miss. Anna "Annie"  female
# 23       1         Sloper, Mr. William Thompson    male
# 24       3        Palsson, Miss. Torborg Danira  female
#
# [16 rows x 3 columns]

# %%
titanic.iloc[0:3, 3] = "anonymous"
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                                     anonymous    male  22.0      1      0
# 1                                     anonymous  female  38.0      1      0
# 2                                     anonymous  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
fruit_sales=pd.DataFrame({
    "Banana":[24,26,24],
    "Apple":[30,45,42]
})
fruit_sales
# Out:
#    Banana  Apple
# 0      24     30
# 1      26     45
# 2      24     42

# %%
fruit_sales["Apple"][2]=45

# %%
fruit_sales
# Out:
#    Banana  Apple
# 0      24     30
# 1      26     45
# 2      24     45

# %%
fruit_sales=pd.DataFrame({
    "Banana":[24,26,24],
    "Apple":[30,45,42]
},
index=['1st month sale','2nd month sale','3rd month sale'])

# %%
fruit_sales
# Out:
#                 Banana  Apple
# 1st month sale      24     30
# 2nd month sale      26     45
# 3rd month sale      24     42

# %% [markdown]
# # Series

# %%
num=pd.Series([1,2,3,4],name="Num")

# %%
num
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: Num, dtype: int64

# %%
pd.Series([1,2,3,4],name="Num")
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: Num, dtype: int64

# %%
type(num)
# Out:
# pandas.core.series.Series

# %%
num.shape
# Out:
# (4,)

# %%
pd.Series([23,34,24],index=['1st','2nd','3rd'],name='Age')
# Out:
# 1st    23
# 2nd    34
# 3rd    24
# Name: Age, dtype: int64

# %% [markdown]
# # Indexing , Selecting and Assigning

# %%
titanic.Name #via object notation
# Out:
# 0                                     anonymous
# 1                                     anonymous
# 2                                     anonymous
#                          ...
# 888    Johnston, Miss. Catherine Helen "Carrie"
# 889                       Behr, Mr. Karl Howell
# 890                         Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic["Name"] #via indexing operator(it's advantageous)
# Out:
# 0                                     anonymous
# 1                                     anonymous
# 2                                     anonymous
#                          ...
# 888    Johnston, Miss. Catherine Helen "Carrie"
# 889                       Behr, Mr. Karl Howell
# 890                         Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic.iloc[0] #fetches row with 0 index
# Out:
# PassengerId       1
# Survived          0
# Pclass            3
#                ...
# Fare           7.25
# Cabin           NaN
# Embarked          S
# Name: 0, Length: 12, dtype: object

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                                     anonymous    male  22.0      1      0
# 1                                     anonymous  female  38.0      1      0
# 2                                     anonymous  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
titanic.iloc[:,0] #: means everything ,here take all rows for their value with 0th column
# Out:
# 0        1
# 1        2
# 2        3
#       ...
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
titanic.iloc[1:3,0]
# Out:
# 1    2
# 2    3
# Name: PassengerId, dtype: int64

# %%
titanic.iloc[:3,2]
# Out:
# 0    3
# 1    1
# 2    3
# Name: Pclass, dtype: int64

# %%
titanic.iloc[[0,1,2],3]
# Out:
# 0    anonymous
# 1    anonymous
# 2    anonymous
# Name: Name, dtype: object

# %%
titanic.tail(5)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.iloc[-5:]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
titanic.loc[0,'Name']
# Out:
# 'anonymous'

# %%
titanic.loc[0,['PassengerId','Survived','Pclass','Name']]
# Out:
# PassengerId            1
# Survived               0
# Pclass                 3
# Name           anonymous
# Name: 0, dtype: object

# %%
titanic.set_index("Age")
# Out:
#       PassengerId  Survived  Pclass                                      Name  \
# Age
# 22.0            1         0       3                                 anonymous
# 38.0            2         1       1                                 anonymous
# 26.0            3         1       3                                 anonymous
# ...           ...       ...     ...                                       ...
# NaN           889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 26.0          890         1       1                     Behr, Mr. Karl Howell
# 32.0          891         0       3                       Dooley, Mr. Patrick
#
#          Sex  SibSp  Parch            Ticket     Fare Cabin Embarked
# Age
# 22.0    male      1      0         A/5 21171   7.2500   NaN        S
# 38.0  female      1      0          PC 17599  71.2833   C85        C
# 26.0  female      0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                                     anonymous    male  22.0      1      0
# 1                                     anonymous  female  38.0      1      0
# 2                                     anonymous  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked  index_backwards
# 0         A/5 21171   7.2500   NaN        S              891
# 1          PC 17599  71.2833   C85        C              890
# 2  STON/O2. 3101282   7.9250   NaN        S              889
# ...

# %%
titanic[titanic["Sex"]=="male"]
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 0              1         0       3                 anonymous  male  22.0
# 4              5         0       3  Allen, Mr. William Henry  male  35.0
# 5              6         0       3          Moran, Mr. James  male   NaN
# ..           ...       ...     ...                       ...   ...   ...
# 886          887         0       2     Montvila, Rev. Juozas  male  27.0
# 889          890         1       1     Behr, Mr. Karl Howell  male  26.0
# 890          891         0       3       Dooley, Mr. Patrick  male  32.0
#
#      SibSp  Parch     Ticket     Fare Cabin Embarked
# 0        1      0  A/5 21171   7.2500   NaN        S
# 4        0      0     373450   8.0500   NaN        S
# 5        0      0     330877   8.4583   NaN        Q
# ..     ...    ...        ...      ...   ...      ...
# 886      0      0     211536  13.0000   NaN        S
# 889      0      0     111369  30.0000  C148        C
# ...

# %%
titanic.loc[titanic["Sex"]=="male"]
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 0              1         0       3                 anonymous  male  22.0
# 4              5         0       3  Allen, Mr. William Henry  male  35.0
# 5              6         0       3          Moran, Mr. James  male   NaN
# ..           ...       ...     ...                       ...   ...   ...
# 886          887         0       2     Montvila, Rev. Juozas  male  27.0
# 889          890         1       1     Behr, Mr. Karl Howell  male  26.0
# 890          891         0       3       Dooley, Mr. Patrick  male  32.0
#
#      SibSp  Parch     Ticket     Fare Cabin Embarked
# 0        1      0  A/5 21171   7.2500   NaN        S
# 4        0      0     373450   8.0500   NaN        S
# 5        0      0     330877   8.4583   NaN        Q
# ..     ...    ...        ...      ...   ...      ...
# 886      0      0     211536  13.0000   NaN        S
# 889      0      0     111369  30.0000  C148        C
# ...

# %%
len(titanic)
# Out:
# 891

# %%
titanic['index_backwards'] = range(len(titanic), 0, -1)
titanic['index_backwards']
# Out:
# 0      891
# 1      890
# 2      889
#       ...
# 888      3
# 889      2
# 890      1
# Name: index_backwards, Length: 891, dtype: int64

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# ...            ...         ...         ...         ...         ...
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  index_backwards
# count  891.000000  891.000000       891.000000
# mean     0.381594   32.204208       446.000000
# std      0.806057   49.693429       257.353842
# ...           ...         ...              ...
# 50%      0.000000   14.454200       446.000000
# 75%      0.000000   31.000000       668.500000
# max      6.000000  512.329200       891.000000
#
# [8 rows x 8 columns]

# %%
titanic["Age"].describe()
# Out:
# count    714.000000
# mean      29.699118
# std       14.526497
#             ...
# 50%       28.000000
# 75%       38.000000
# max       80.000000
# Name: Age, Length: 8, dtype: float64

# %%
titanic["Name"].describe()
# Out:
# count           891
# unique          889
# top       anonymous
# freq              3
# Name: Name, dtype: object

# %%
titanic["Survived"].mean()
# Out:
# 0.3838383838383838

# %%
titanic["Name"].unique()
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth',
#        'Saundercock, Mr. William Henry', 'Andersson, Mr. Anders Johan',
#        'Vestrom, Miss. Hulda Amanda Adolfina',
#        'Hewlett, Mrs. (Mary D Kingcome) ', 'Rice, Master. Eugene',
#        'Williams, Mr. Charles Eugene',
#        'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#        'Masselmani, Mrs. Fatima', 'Fynney, Mr. Joseph J',
#        'Beesley, Mr. Lawrence', 'McGowan, Miss. Anna "Annie"',
# ...

# %%
titanic["Age"].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
# 30.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 32.00    18
# 35.00    18
# 27.00    18
# 26.00    18
# 16.00    17
# 31.00    17
# 20.00    15
# 34.00    15
# 33.00    15
# 23.00    15
# 39.00    14
# 40.00    13
# 17.00    13
# 42.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 44.00     9
# 48.00     9
# 47.00     9
# 54.00     8
# 9.00      8
# 1.00      7
# 51.00     7
# 14.00     6
# 52.00     6
# 37.00     6
# 49.00     6
# 41.00     6
# 3.00      6
# 58.00     5
# 15.00     5
# 43.00     5
# 62.00     4
# 56.00     4
# 5.00      4
# 11.00     4
# 60.00     4
# 8.00      4
# 6.00      3
# 46.00     3
# 61.00     3
# 65.00     3
# 7.00      3
# 10.00     2
# 64.00     2
# 13.00     2
# 63.00     2
# 30.50     2
# 57.00     2
# 70.00     2
# 0.75      2
# 71.00     2
# 59.00     2
# 0.83      2
# 40.50     2
# 55.00     2
# 32.50     2
# 28.50     2
# ...

# %%
titanic.groupby("Pclass")["Pclass"].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64

# %%
titanic[["Age","Fare"]].median()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
titanic.agg({
    "Age":["min","max","skew","median"],
    "Fare":["min","max","mean"],
})
# Out:
#               Age        Fare
# min      0.420000    0.000000
# max     80.000000  512.329200
# skew     0.389108         NaN
# median  28.000000         NaN
# mean          NaN   32.204208

# %%
titanic[["Sex","Age"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
titanic.groupby("Sex").mean(numeric_only=True)
# Out:
#         PassengerId  Survived    Pclass        Age     SibSp     Parch  \
# Sex
# female   431.028662  0.742038  2.159236  27.915709  0.694268  0.649682
# male     454.147314  0.188908  2.389948  30.726645  0.429809  0.235702
#
#              Fare
# Sex
# female  44.479818
# male    25.523893

# %%
titanic.groupby("Sex")["Age"].mean()
# Out:
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
titanic.groupby(["Sex","Pclass"])["Fare"].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %% [markdown]
# # Creating plot in pandas

# %%
import matplotlib.pyplot as plt

# %%
air_quality=pd.read_csv("air_quality_no2.csv")

# %%
air_quality
# Out:
#                  datetime  station_antwerp  station_paris  station_london
# 0     2019-05-07 02:00:00              NaN            NaN            23.0
# 1     2019-05-07 03:00:00             50.5           25.0            19.0
# 2     2019-05-07 04:00:00             45.0           27.7            19.0
# ...                   ...              ...            ...             ...
# 1032  2019-06-21 00:00:00              NaN           26.5             NaN
# 1033  2019-06-21 01:00:00              NaN           21.8             NaN
# 1034  2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 4 columns]

# %%
air_quality=pd.read_csv("air_quality_no2.csv",index_col=0,parse_dates=True)

# %%
#pd.set_option("display.max_rows",None)
air_quality.head(20)
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
# 2019-05-07 07:00:00              NaN           72.4            26.0
# 2019-05-07 08:00:00              NaN           77.7            32.0
# 2019-05-07 09:00:00              NaN           67.9            32.0
# 2019-05-07 10:00:00              NaN           56.0            28.0
# 2019-05-07 11:00:00              NaN           34.5            21.0
# 2019-05-07 12:00:00              NaN           20.1            21.0
# 2019-05-07 13:00:00              NaN           13.0            18.0
# 2019-05-07 14:00:00              NaN           10.6            20.0
# ...

# %%
air_quality.set_index("datetime") #not working rightnow beacuse datetime is already set as index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[89], line 1
# ----> 1 air_quality.set_index("datetime")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:5859, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5856                 missing.append(col)
#    5858 if missing:
# -> 5859     raise KeyError(f"None of {missing} are in the columns")
#    5861 if inplace:
#    5862     frame = self
#
# KeyError: "None of ['datetime'] are in the columns"

# %%
air_quality.set_index("station_antwerp")
# Out:
#                  station_paris  station_london
# station_antwerp
# NaN                        NaN            23.0
# 50.5                      25.0            19.0
# 45.0                      27.7            19.0
# ...                        ...             ...
# NaN                       26.5             NaN
# NaN                       21.8             NaN
# NaN                       20.0             NaN
#
# [1035 rows x 2 columns]

# %%
air_quality
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# ...                              ...            ...             ...
# 2019-06-21 00:00:00              NaN           26.5             NaN
# 2019-06-21 01:00:00              NaN           21.8             NaN
# 2019-06-21 02:00:00              NaN           20.0             NaN
#
# [1035 rows x 3 columns]

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality.plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
plt.show()

# %%
air_quality["station_paris"].plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
air_quality.plot.scatter(x="station_london",y="station_paris",alpha=0.5)
# Out:
# <Axes: xlabel='station_london', ylabel='station_paris'>

# %%
air_quality.plot.#tab
# Out:
#   Cell In[119], line 1
#     air_quality.plot.#tab
#                      ^
# SyntaxError: invalid syntax

# %%
air_quality.plot.box() #apart from boxplot also known as box and whisker plot
# Out:
# <Axes: >

# %%
air_quality.plot.area(subplots=True,figsize=(10,5))
# Out:
# array([<Axes: xlabel='datetime'>, <Axes: xlabel='datetime'>,
#        <Axes: xlabel='datetime'>], dtype=object)

# %%
fig,axs=plt.subplots(figsize=(12,5))

# %%
fig, axs = plt.subplots(figsize=(12, 4))

air_quality.plot.area(ax=axs)


axs.set_ylabel("NO$_2$ concentration")
axs.set_xlabel("Date")


#fig.savefig("no2_concentrations.png")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# # Creating new column from existing column

# %%
air_quality["Concentration in mg/m**3)"]=air_quality["station_london"]*1.882

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      Concentration in mg/m**3
# datetime
# 2019-05-07 02:00:00                    43.286
# 2019-05-07 03:00:00                    35.758
# 2019-05-07 04:00:00                    35.758
# 2019-05-07 05:00:00                    30.112
# 2019-05-07 06:00:00                       NaN

# %%
air_quality["ratio_paris_antwerp"]=(air_quality["station_paris"]/air_quality["station_antwerp"])

# %%
air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      Concentration in mg/m**3  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00                    43.286                  NaN
# 2019-05-07 03:00:00                    35.758             0.495050
# 2019-05-07 04:00:00                    35.758             0.615556
# 2019-05-07 05:00:00                    30.112                  NaN
# 2019-05-07 06:00:00                       NaN                  NaN

# %%
air_quality_renamed=air_quality.rename(
columns={
    "station_antwerp":"BETR801",
    "station_paris":"FR04014",
    "station_london":"London Westminster",
})

# %%
air_quality_renamed.head()
# Out:
#                      BETR801  FR04014  London Westminster  \
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
#
#                      Concentration in mg/m**3  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00                    43.286                  NaN
# 2019-05-07 03:00:00                    35.758             0.495050
# 2019-05-07 04:00:00                    35.758             0.615556
# 2019-05-07 05:00:00                    30.112                  NaN
# 2019-05-07 06:00:00                       NaN                  NaN

# %%
air_quality_renamed=air_quality_renamed.rename(columns=str.lower)

# %%
air_quality_renamed.head()
# Out:
#                      betr801  fr04014  london westminster  \
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
#
#                      concentration in mg/m**3  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00                    43.286                  NaN
# 2019-05-07 03:00:00                    35.758             0.495050
# 2019-05-07 04:00:00                    35.758             0.615556
# 2019-05-07 05:00:00                    30.112                  NaN
# 2019-05-07 06:00:00                       NaN                  NaN
